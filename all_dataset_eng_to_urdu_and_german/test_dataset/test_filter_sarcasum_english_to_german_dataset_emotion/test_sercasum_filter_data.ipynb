# %%
import pandas as pd

# %%
df = pd.read_csv("/content/en_test_with_labels.csv")

# %%
df
# Out:
#                                                    text    binary  \
# 0     #USER# #USER# #USER# Booked at Northampton on ...      Hope
# 1     There're 2 types of lawmakers. And you only fi...  Not Hope
# 2     #USER# #USER# #USER# #USER# What if The parent...  Not Hope
# 3     #USER# #USER# #USER# #USER# #USER# #USER# #USE...      Hope
# 4     #USER# #USER# If you don’t believe in abortion...  Not Hope
# ...                                                 ...       ...
# 2375  No. I'll type slowly so I don't get ahead of y...  Not Hope
# 2376  #USER# This is the level of enjoyment I aspire...      Hope
# 2377  #USER# Embarrassed by your airlines. Delays, o...      Hope
# 2378  OH HELL NAW! They deadass out here making choc...      Hope
# 2379  #USER# #USER# #USER# #USER# Do what now?!? The...  Not Hope
#
#             multiclass
# 0     Generalized Hope
# 1             Not Hope
# 2             Not Hope
# 3       Realistic Hope
# 4             Not Hope
# ...                ...
# 2375           Sarcasm
# 2376  Generalized Hope
# 2377  Generalized Hope
# 2378  Unrealistic Hope
# 2379          Not Hope
#
# [2380 rows x 3 columns]

# %%
len(df)
# Out:
# 2380

# %%
sarcasm_data = df[df['multiclass'] == 'Sarcasm'].copy()

print(f"Sarcasm rows found: {len(sarcasm_data)}")
# Out:
# Sarcasm rows found: 315

# %%
sarcasm_data.to_csv("en_test_with_sarcasm.csv", index = False )

# %%
print(f"✅ New file created: /content/en_test_with_labels.csv")
print(f"✅ Contains: {len(sarcasm_data)} sarcasm rows")
# Out:
# ✅ New file created: /content/en_test_with_labels.csv
# ✅ Contains: 315 sarcasm rows

# %%
print(f"\n🎯 DONE! Your sarcasm file is ready!")
# Out:
# 🎯 DONE! Your sarcasm file is ready!
